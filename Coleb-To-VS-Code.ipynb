# %% [markdown]
# # Colab to VS Code Automation
#
# This notebook supports two modes:
#
# - Chat inside Colab
# - API mode for VS Code / Continue

# %%
# !pip install -q colab-xterm

# %%
# %load_ext colabxterm
# %xterm

# %% [markdown]
# The repository URL is already set to your GitHub repo.

# %%
REPO_URL = "https://github.com/MasudRana0q/ColebToVSCode.git"
REPO_DIR = "/content/ColebToVSCode"

# %%
# !rm -rf "$REPO_DIR"
# !git clone "$REPO_URL" "$REPO_DIR"
# %cd $REPO_DIR
# !chmod +x colab_ai.sh

# %% [markdown]
# Run setup once per runtime.

# %%
# !bash colab_ai.sh setup

# %% [markdown]
# Choose one mode below.
#
# For chat mode, do not run `!bash colab_ai.sh chat` in a normal notebook cell.
#
# Open the xterm terminal above and run:
#
# ```bash
# cd /content/ColebToVSCode
# bash colab_ai.sh chat
# ```
#
# This keeps your typing visible as normal text.

# %%
print("Open xterm and run: cd /content/ColebToVSCode && bash colab_ai.sh chat")

# %% [markdown]
# For VS Code / Continue API mode, run the next cell instead. It prints the current Tailscale IP and a Continue-ready config.

# %%
# !bash colab_ai.sh api

# %%
# !bash colab_ai.sh status
